# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split,cross_val_score,KFold
from sklearn import metrics
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import cross_validate
from sklearn import linear_model
from sklearn import preprocessing
import warnings
warnings.filterwarnings('ignore')
cvk=KFold(n_splits=5)

# %%
# %%HTML
# <style type="text/css">
# table.dataframe td, table.dataframe th {
#     border: 1px  black solid !important;
#   color: black !important;
# }
# </style>
# Out:
# <style type="text/css">
# table.dataframe td, table.dataframe th {
#     border: 1px  black solid !important;
#   color: black !important;
# }
# </style>

# %%
def scores_report(model, parameters):
    model_GS = GridSearchCV(model, param_grid=parameters, scoring='neg_mean_squared_error', cv = 3, iid = False, return_train_score=True, n_jobs=-1)
    model_RS = RandomizedSearchCV(estimator = model, param_distributions = parameters,scoring='neg_mean_squared_error', cv=3, n_iter=5, iid=False,return_train_score=True, n_jobs=-1)
    scores_GS = cross_validate(model_GS, X, y, return_train_score=True, scoring=('neg_mean_absolute_error', 'neg_mean_squared_error', 'neg_median_absolute_error'),cv=cvk)
    scores_RS = cross_validate(model_RS,X, y, return_train_score=True, scoring=('neg_mean_absolute_error', 'neg_mean_squared_error', 'neg_median_absolute_error'),cv=cvk)
    return scores_GS, scores_RS

# %%
def result_line(model:str, search_strategy:str, results):
    for key, value in results.items():
        results[key] = results[key].mean()
    results['Model'] = model
    results['Search_strategy'] = search_strategy
    return results

# %% [markdown]
# <h1>HOUSING DB</h1>

# %%
namesCol = ["CRIM", "ZN", "INDUS", "CHAS", "NOX", "RM", "AGE", "DIS", "RAD", "TAX", "PTRATIO", "B", "LSTAT", "MEDV"]
df = pd.read_csv('housing.data',delimiter='\s+' ,names=namesCol)
X=df.iloc[:,:13].values
y=np.ravel(df.iloc[:,13:])
lab_enc=preprocessing.LabelEncoder()
y= lab_enc.fit_transform(y)
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1/3)#,stratify=y)

# %%
results = pd.DataFrame(columns = ['Model','Search_strategy','train_neg_mean_absolute_error', 'train_neg_mean_squared_error', 'train_neg_median_absolute_error', 'test_neg_mean_absolute_error', 'test_neg_mean_squared_error', 'test_neg_median_absolute_error', 'fit_time', 'score_time'])
results
# Out:
# Empty DataFrame
# Columns: [Model, Search_strategy, train_neg_mean_absolute_error, train_neg_mean_squared_error, train_neg_median_absolute_error, test_neg_mean_absolute_error, test_neg_mean_squared_error, test_neg_median_absolute_error, fit_time, score_time]
# Index: []

# %% [markdown]
# <h2 style="color:purple;"><i>Logistic Regression</i></h2>

# %%
model1=linear_model.LogisticRegression()
model1.fit(X,y)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
parameters={
    'solver': ['lbfgs'],
    'C':[0.1, 1.0, 2, 3, 5, 13, 21],
    'max_iter':[100, 200, 300, 500]
}
res_GS, res_RS = scores_report(model1, parameters=parameters)

res_GS = result_line('Logistic Regression', 'GridSearchCV', res_GS)
res_RS = result_line('Logistic Regression', 'RandomSearchCV', res_RS)
results = results.append(res_GS, ignore_index=True)
results = results.append(res_RS, ignore_index=True)

# %%
results
# Out:
#                  Model Search_strategy  train_neg_mean_absolute_error  \
# 0  Logistic Regression    GridSearchCV                     -14.597285
# 1  Logistic Regression  RandomSearchCV                     -14.308196
#
#    train_neg_mean_squared_error  train_neg_median_absolute_error  \
# 0                   -681.207123                             -6.4
# 1                   -667.355696                             -5.8
#
#    test_neg_mean_absolute_error  test_neg_mean_squared_error  \
# 0                    -42.435061                 -3592.456067
# 1                    -41.348961                 -3307.097670
#
#    test_neg_median_absolute_error    fit_time  score_time
# 0                           -29.5  389.994207    0.003466
# 1                           -29.5  101.226728    0.001796

# %% [markdown]
# <h2 style="color:dark green;"><i>Ridge Regression</i></h2>

# %%
model2=linear_model.Ridge()
model2.fit(X,y)
# Out:
# Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
parameters = {'alpha':[0.1, 0.5, 1, 2, 3, 6, 8, 11, 1000, 3000]
             }

res_GS, res_RS = scores_report(model2, parameters=parameters)

res_GS = result_line('Ridge Regression', 'GridSearchCV', res_GS)
res_RS = result_line('Ridge Regression', 'RandomSearchCV', res_RS)
results = results.append(res_GS, ignore_index=True)
results = results.append(res_RS, ignore_index=True)

# %%
results
# Out:
#                  Model Search_strategy  train_neg_mean_absolute_error  \
# 0  Logistic Regression    GridSearchCV                     -14.597285
# 1  Logistic Regression  RandomSearchCV                     -14.308196
# 2     Ridge Regression    GridSearchCV                     -20.912789
# 3     Ridge Regression  RandomSearchCV                     -19.798138
#
#    train_neg_mean_squared_error  train_neg_median_absolute_error  \
# 0                   -681.207123                        -6.400000
# 1                   -667.355696                        -5.800000
# 2                   -770.506284                       -16.893021
# 3                   -709.701378                       -15.551839
#
#    test_neg_mean_absolute_error  test_neg_mean_squared_error  \
# 0                    -42.435061                 -3592.456067
# 1                    -41.348961                 -3307.097670
# 2                    -26.395409                 -1183.448821
# 3                    -23.945347                 -1026.559697
#
#    test_neg_median_absolute_error    fit_time  score_time
# 0                      -29.500000  389.994207    0.003466
# 1                      -29.500000  101.226728    0.001796
# 2                      -21.522174    0.071808    0.000998
# 3                      -20.206110    0.040691    0.001197

# %% [markdown]
# <h2 style="color:dark blue;"><i>Bayesian Regression</i></h2>

# %%
model3=linear_model.BayesianRidge()
model3.fit(X,y)
# Out:
# BayesianRidge(alpha_1=1e-06, alpha_2=1e-06, compute_score=False, copy_X=True,
#        fit_intercept=True, lambda_1=1e-06, lambda_2=1e-06, n_iter=300,
#        normalize=False, tol=0.001, verbose=False)

# %%
parameters = {
    'n_iter': [100, 300, 500],
    'alpha_1': [1e-10, 1e-5, 0.001, 1.0, 5.0, 8.0],
    'alpha_2': [1e-10, 1e-5, 0.001, 1.0, 5.0, 8.0],
    'lambda_1':[1e-10, 1e-5, 0.001, 1.0, 5.0, 8.0],
    'lambda_2':[1e-10, 1e-5, 0.001, 1.0, 5.0, 8.0]
} 
res_GS, res_RS = scores_report(model3, parameters=parameters)

res_GS = result_line('Bayesian Regression', 'GridSearchCV', res_GS)
res_RS = result_line('Bayesian Regression', 'RandomSearchCV', res_RS)
results = results.append(res_GS, ignore_index=True)
results = results.append(res_RS, ignore_index=True)

# %%
results
# Out:
#                  Model Search_strategy  train_neg_mean_absolute_error  \
# 0  Logistic Regression    GridSearchCV                     -14.597285
# 1  Logistic Regression  RandomSearchCV                     -14.308196
# 2     Ridge Regression    GridSearchCV                     -20.912789
# 3     Ridge Regression  RandomSearchCV                     -19.798138
# 4  Bayesian Regression    GridSearchCV                     -19.910525
# 5  Bayesian Regression  RandomSearchCV                     -19.759475
#
#    train_neg_mean_squared_error  train_neg_median_absolute_error  \
# 0                   -681.207123                        -6.400000
# 1                   -667.355696                        -5.800000
# 2                   -770.506284                       -16.893021
# 3                   -709.701378                       -15.551839
# 4                   -709.995997                       -15.820315
# 5                   -703.355729                       -15.506893
#
#    test_neg_mean_absolute_error  test_neg_mean_squared_error  \
# 0                    -42.435061                 -3592.456067
# 1                    -41.348961                 -3307.097670
# 2                    -26.395409                 -1183.448821
# 3                    -23.945347                 -1026.559697
# 4                    -24.363661                 -1049.786420
# 5                    -23.942809                 -1030.779749
#
#    test_neg_median_absolute_error    fit_time  score_time
# 0                      -29.500000  389.994207    0.003466
# 1                      -29.500000  101.226728    0.001796
# 2                      -21.522174    0.071808    0.000998
# 3                      -20.206110    0.040691    0.001197
# 4                      -19.598822   18.223869    0.001596
# 5                      -19.264853    0.051263    0.000999

# %% [markdown]
# <h2 style="color:dark orange;"><i>SGD Regressor</i></h2>

# %%
model4=linear_model.SGDRegressor(eta0=0.000001)
model4.fit(X,y)
# Out:
# SGDRegressor(alpha=0.0001, average=False, early_stopping=False, epsilon=0.1,
#        eta0=1e-06, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='invscaling', loss='squared_loss', max_iter=None,
#        n_iter=None, n_iter_no_change=5, penalty='l2', power_t=0.25,
#        random_state=None, shuffle=True, tol=None, validation_fraction=0.1,
#        verbose=0, warm_start=False)

# %%
parameters={
    'loss':['squared_loss', 'huber', 'squared_epsilon_insensitive'],
    'penalty':['l1', 'l2', 'elasticnet'],
    'alpha':[1e-8, 1e-3, 0.5, 3, 8],
    'max_iter':[200, 300, 800]
    
}
res_GS, res_RS = scores_report(model4, parameters=parameters)

res_GS = result_line('SGD Regressor', 'GridSearchCV', res_GS)
res_RS = result_line('SGD Regressor', 'RandomSearchCV', res_RS)
results = results.append(res_GS, ignore_index=True)
results = results.append(res_RS, ignore_index=True)

# %%
results
# Out:
#                  Model Search_strategy  train_neg_mean_absolute_error  \
# 0  Logistic Regression    GridSearchCV                     -14.597285
# 1  Logistic Regression  RandomSearchCV                     -14.308196
# 2     Ridge Regression    GridSearchCV                     -20.912789
# 3     Ridge Regression  RandomSearchCV                     -19.798138
# 4  Bayesian Regression    GridSearchCV                     -19.910525
# 5  Bayesian Regression  RandomSearchCV                     -19.759475
# 6        SGD Regressor    GridSearchCV                     -31.960363
# 7        SGD Regressor  RandomSearchCV                     -33.314163
#
#    train_neg_mean_squared_error  train_neg_median_absolute_error  \
# 0                   -681.207123                        -6.400000
# 1                   -667.355696                        -5.800000
# 2                   -770.506284                       -16.893021
# 3                   -709.701378                       -15.551839
# 4                   -709.995997                       -15.820315
# 5                   -703.355729                       -15.506893
# 6                  -1581.488168                       -27.551934
# 7                  -1741.073343                       -28.265883
#
#    test_neg_mean_absolute_error  test_neg_mean_squared_error  \
# 0                    -42.435061                 -3592.456067
# 1                    -41.348961                 -3307.097670
# 2                    -26.395409                 -1183.448821
# 3                    -23.945347                 -1026.559697
# 4                    -24.363661                 -1049.786420
# 5                    -23.942809                 -1030.779749
# 6                    -40.666508                 -2693.696700
# 7                    -42.747908                 -2960.719077
#
#    test_neg_median_absolute_error    fit_time  score_time
# 0                      -29.500000  389.994207    0.003466
# 1                      -29.500000  101.226728    0.001796
# 2                      -21.522174    0.071808    0.000998
# 3                      -20.206110    0.040691    0.001197
# 4                      -19.598822   18.223869    0.001596
# 5                      -19.264853    0.051263    0.000999
# 6                      -32.067472    4.377893    0.000997
# 7                      -34.563756    0.260103    0.000799

# %% [markdown]
# <h2 style="color:dark violet;"><i>Perceptron</i></h2>

# %%
model5=linear_model.Perceptron(eta0=0.000001)
model5.fit(X,y)
# Out:
# Perceptron(alpha=0.0001, class_weight=None, early_stopping=False, eta0=1e-06,
#       fit_intercept=True, max_iter=None, n_iter=None, n_iter_no_change=5,
#       n_jobs=None, penalty=None, random_state=0, shuffle=True, tol=None,
#       validation_fraction=0.1, verbose=0, warm_start=False)

# %%
parameters= {
    'alpha':[1e-5, 1e-3, 0.5, 1, 8, 21],
    'max_iter': [200, 500, 800]
}
res_GS, res_RS = scores_report(model5, parameters=parameters)

res_GS = result_line('Perceptron', 'GridSearchCV', res_GS)
res_RS = result_line('Perceptron', 'RandomSearchCV', res_RS)
results = results.append(res_GS, ignore_index=True)
results = results.append(res_RS, ignore_index=True)

# %%
results
# Out:
#                  Model Search_strategy  train_neg_mean_absolute_error  \
# 0  Logistic Regression    GridSearchCV                     -14.597285
# 1  Logistic Regression  RandomSearchCV                     -14.308196
# 2     Ridge Regression    GridSearchCV                     -20.912789
# 3     Ridge Regression  RandomSearchCV                     -19.798138
# 4  Bayesian Regression    GridSearchCV                     -19.910525
# 5  Bayesian Regression  RandomSearchCV                     -19.759475
# 6        SGD Regressor    GridSearchCV                     -31.960363
# 7        SGD Regressor  RandomSearchCV                     -33.314163
# 8           Perceptron    GridSearchCV                     -47.608839
# 9           Perceptron  RandomSearchCV                     -47.355999
#
#    train_neg_mean_squared_error  train_neg_median_absolute_error  \
# 0                   -681.207123                        -6.400000
# 1                   -667.355696                        -5.800000
# 2                   -770.506284                       -16.893021
# 3                   -709.701378                       -15.551839
# 4                   -709.995997                       -15.820315
# 5                   -703.355729                       -15.506893
# 6                  -1581.488168                       -27.551934
# 7                  -1741.073343                       -28.265883
# 8                  -4046.851758                       -39.400000
# 9                  -4036.677931                       -39.000000
#
#    test_neg_mean_absolute_error  test_neg_mean_squared_error  \
# 0                    -42.435061                 -3592.456067
# 1                    -41.348961                 -3307.097670
# 2                    -26.395409                 -1183.448821
# 3                    -23.945347                 -1026.559697
# 4                    -24.363661                 -1049.786420
# 5                    -23.942809                 -1030.779749
# 6                    -40.666508                 -2693.696700
# 7                    -42.747908                 -2960.719077
# 8                    -64.641739                 -6654.036847
# 9                    -64.334809                 -6672.957639
#
#    test_neg_median_absolute_error    fit_time  score_time
# 0                      -29.500000  389.994207    0.003466
# 1                      -29.500000  101.226728    0.001796
# 2                      -21.522174    0.071808    0.000998
# 3                      -20.206110    0.040691    0.001197
# 4                      -19.598822   18.223869    0.001596
# 5                      -19.264853    0.051263    0.000999
# 6                      -32.067472    4.377893    0.000997
# 7                      -34.563756    0.260103    0.000799
# 8                      -61.800000   57.562280    0.003593
# 9                      -59.800000   17.984905    0.011370

# %%
results.iloc[:, 2:] = abs(results.iloc[:, 2:])

# %%
def color(grid):
    return ['background-color: red' if value == grid.max() else ('background-color: green' if value == grid.min() else '') for value in grid]

results_highlighted= results.style.apply(color, subset=['train_neg_mean_absolute_error', 'train_neg_mean_squared_error', 'train_neg_median_absolute_error','test_neg_mean_absolute_error','test_neg_mean_squared_error','test_neg_median_absolute_error','fit_time','score_time'])

results_highlighted
# Out:
# <style  type="text/css" >
#     #T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674row0_col8 {
#             background-color:  red;
#         }    #T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674row1_col2 {
#             background-color:  green;
#         }    #T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674row1_col3 {
#             background-color:  green;
#         }    #T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674row1_col4 {
#             background-color:  green;
#         }    #T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674row3_col6 {
#             background-color:  green;
#         }    #T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674row3_col8 {
#             background-color:  green;
#         }    #T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674row5_col5 {
#             background-color:  green;
#         }    #T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674row5_col7 {
#             background-color:  green;
#         }    #T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674row7_col9 {
#             background-color:  green;
#         }    #T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674row8_col2 {
#             background-color:  red;
#         }    #T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674row8_col3 {
#             background-color:  red;
#         }    #T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674row8_col4 {
#             background-color:  red;
#         }    #T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674row8_col5 {
#             background-color:  red;
#         }    #T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674row8_col7 {
#             background-color:  red;
#         }    #T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674row9_col6 {
#             background-color:  red;
#         }    #T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674row9_col9 {
#             background-color:  red;
#         }</style>
# <table id="T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Model</th>
#         <th class="col_heading level0 col1" >Search_strategy</th>
#         <th class="col_heading level0 col2" >train_neg_mean_absolute_error</th>
#         <th class="col_heading level0 col3" >train_neg_mean_squared_error</th>
#         <th class="col_heading level0 col4" >train_neg_median_absolute_error</th>
#         <th class="col_heading level0 col5" >test_neg_mean_absolute_error</th>
#         <th class="col_heading level0 col6" >test_neg_mean_squared_error</th>
#         <th class="col_heading level0 col7" >test_neg_median_absolute_error</th>
#         <th class="col_heading level0 col8" >fit_time</th>
#         <th class="col_heading level0 col9" >score_time</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674row0_col0" class="data row0 col0" >Logistic Regression</td>
#         <td id="T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674row0_col1" class="data row0 col1" >GridSearchCV</td>
#         <td id="T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674row0_col2" class="data row0 col2" >14.5973</td>
#         <td id="T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674row0_col3" class="data row0 col3" >681.207</td>
#         <td id="T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674row0_col4" class="data row0 col4" >6.4</td>
#         <td id="T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674row0_col5" class="data row0 col5" >42.4351</td>
#         <td id="T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674row0_col6" class="data row0 col6" >3592.46</td>
#         <td id="T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674row0_col7" class="data row0 col7" >29.5</td>
#         <td id="T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674row0_col8" class="data row0 col8" >389.994</td>
#         <td id="T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674row0_col9" class="data row0 col9" >0.00346584</td>
#     </tr>    <tr>
#         <th id="T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674row1_col0" class="data row1 col0" >Logistic Regression</td>
#         <td id="T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674row1_col1" class="data row1 col1" >RandomSearchCV</td>
#         <td id="T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674row1_col2" class="data row1 col2" >14.3082</td>
#         <td id="T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674row1_col3" class="data row1 col3" >667.356</td>
#         <td id="T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674row1_col4" class="data row1 col4" >5.8</td>
#         <td id="T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674row1_col5" class="data row1 col5" >41.349</td>
#         <td id="T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674row1_col6" class="data row1 col6" >3307.1</td>
#         <td id="T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674row1_col7" class="data row1 col7" >29.5</td>
#         <td id="T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674row1_col8" class="data row1 col8" >101.227</td>
#         <td id="T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674row1_col9" class="data row1 col9" >0.00179567</td>
#     </tr>    <tr>
#         <th id="T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674row2_col0" class="data row2 col0" >Ridge Regression</td>
#         <td id="T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674row2_col1" class="data row2 col1" >GridSearchCV</td>
#         <td id="T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674row2_col2" class="data row2 col2" >20.9128</td>
#         <td id="T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674row2_col3" class="data row2 col3" >770.506</td>
#         <td id="T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674row2_col4" class="data row2 col4" >16.893</td>
#         <td id="T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674row2_col5" class="data row2 col5" >26.3954</td>
#         <td id="T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674row2_col6" class="data row2 col6" >1183.45</td>
#         <td id="T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674row2_col7" class="data row2 col7" >21.5222</td>
#         <td id="T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674row2_col8" class="data row2 col8" >0.0718083</td>
#         <td id="T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674row2_col9" class="data row2 col9" >0.000997877</td>
#     </tr>    <tr>
#         <th id="T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674level0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674row3_col0" class="data row3 col0" >Ridge Regression</td>
#         <td id="T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674row3_col1" class="data row3 col1" >RandomSearchCV</td>
#         <td id="T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674row3_col2" class="data row3 col2" >19.7981</td>
#         <td id="T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674row3_col3" class="data row3 col3" >709.701</td>
#         <td id="T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674row3_col4" class="data row3 col4" >15.5518</td>
#         <td id="T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674row3_col5" class="data row3 col5" >23.9453</td>
#         <td id="T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674row3_col6" class="data row3 col6" >1026.56</td>
#         <td id="T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674row3_col7" class="data row3 col7" >20.2061</td>
#         <td id="T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674row3_col8" class="data row3 col8" >0.0406912</td>
#         <td id="T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674row3_col9" class="data row3 col9" >0.00119691</td>
#     </tr>    <tr>
#         <th id="T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674level0_row4" class="row_heading level0 row4" >4</th>
#         <td id="T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674row4_col0" class="data row4 col0" >Bayesian Regression</td>
#         <td id="T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674row4_col1" class="data row4 col1" >GridSearchCV</td>
#         <td id="T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674row4_col2" class="data row4 col2" >19.9105</td>
#         <td id="T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674row4_col3" class="data row4 col3" >709.996</td>
#         <td id="T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674row4_col4" class="data row4 col4" >15.8203</td>
#         <td id="T_97ccf2ca_7038_11e9_9f4c_54ab3ac1d674row4_col5" class="data row4 col5" >24.3637</td>
#         <td id="T_97ccf2ca_7038
