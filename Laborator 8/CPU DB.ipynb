# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split,cross_val_score,KFold
from sklearn import metrics
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import cross_validate
from sklearn import linear_model
from sklearn import preprocessing
import warnings
warnings.filterwarnings('ignore')
cvk=KFold(n_splits=5)

# %%
# %%HTML
# <style type="text/css">
# table.dataframe td, table.dataframe th {
#     border: 1px  black solid !important;
#   color: black !important;
# }
# </style>
# Out:
# <style type="text/css">
# table.dataframe td, table.dataframe th {
#     border: 1px  black solid !important;
#   color: black !important;
# }
# </style>

# %%
def scores_report(model, parameters):
    model_GS = GridSearchCV(model, param_grid=parameters, scoring='neg_mean_squared_error', cv = 3, iid = False, return_train_score=True, n_jobs=-1)
    model_RS = RandomizedSearchCV(estimator = model, param_distributions = parameters,scoring='neg_mean_squared_error', cv=3, n_iter=5, iid=False,return_train_score=True, n_jobs=-1)
    scores_GS = cross_validate(model_GS, X, y, return_train_score=True, scoring=('neg_mean_absolute_error', 'neg_mean_squared_error', 'neg_median_absolute_error'),cv=cvk)
    scores_RS = cross_validate(model_RS,X, y, return_train_score=True, scoring=('neg_mean_absolute_error', 'neg_mean_squared_error', 'neg_median_absolute_error'),cv=cvk)
    return scores_GS, scores_RS

# %%
def result_line(model:str, search_strategy:str, results):
    for key, value in results.items():
        results[key] = results[key].mean()
    results['Model'] = model
    results['Search_strategy'] = search_strategy
    return results

# %% [markdown]
# <h1>MACHINE DB</h1>

# %%
namesCol = ["Vendor Name", "Model Name", "MYCT", "MMIN", "MMAX", "CACH", "CHMIN", "CHMAX", "PRP", "ERP"]
df = pd.read_csv("machine.data",names=namesCol )
X=df.iloc[:,2:8]
y=np.ravel(df.iloc[:,8:9])
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1/3)#,stratify=y)

# %%
results = pd.DataFrame(columns = ['Model','Search_strategy','train_neg_mean_absolute_error', 'train_neg_mean_squared_error', 'train_neg_median_absolute_error', 'test_neg_mean_absolute_error', 'test_neg_mean_squared_error', 'test_neg_median_absolute_error', 'fit_time', 'score_time'])
pd.options.display.float_format = '{:2,.5f}'.format
results
# Out:
# Empty DataFrame
# Columns: [Model, Search_strategy, train_neg_mean_absolute_error, train_neg_mean_squared_error, train_neg_median_absolute_error, test_neg_mean_absolute_error, test_neg_mean_squared_error, test_neg_median_absolute_error, fit_time, score_time]
# Index: []

# %% [markdown]
# <h2 style="color:purple;"><i>Logistic Regression</i></h2>

# %%
model1=linear_model.LogisticRegression()
model1.fit(X,y)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
parameters={
    'solver': ['lbfgs'],
    'C':[0.1, 1.0, 2, 3, 5, 13, 21],
    'max_iter':[100, 200, 300, 500]
}
res_GS, res_RS = scores_report(model1, parameters=parameters)

res_GS = result_line('Logistic Regression', 'GridSearchCV', res_GS)
res_RS = result_line('Logistic Regression', 'RandomSearchCV', res_RS)
results = results.append(res_GS, ignore_index=True)
results = results.append(res_RS, ignore_index=True)

# %%
results
# Out:
#                  Model Search_strategy  train_neg_mean_absolute_error  \
# 0  Logistic Regression    GridSearchCV                      -14.29677
# 1  Logistic Regression  RandomSearchCV                      -14.28360
#
#    train_neg_mean_squared_error  train_neg_median_absolute_error  \
# 0                    -958.82546                         -3.20000
# 1                    -999.73923                         -2.60000
#
#    test_neg_mean_absolute_error  test_neg_mean_squared_error  \
# 0                     -58.53833                -17,219.19547
# 1                     -61.64309                -17,748.60499
#
#    test_neg_median_absolute_error  fit_time  score_time
# 0                       -19.40000  87.50960     0.00280
# 1                       -20.80000  19.08596     0.00319

# %% [markdown]
# <h2 style="color:dark green;"><i>Ridge Regression</i></h2>

# %%
model2=linear_model.Ridge()
model2.fit(X,y)
# Out:
# Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
parameters = {'alpha':[0.1, 0.5, 1, 2, 3, 6, 8, 11, 1000, 3000]
             }

res_GS, res_RS = scores_report(model2, parameters=parameters)

res_GS = result_line('Ridge Regression', 'GridSearchCV', res_GS)
res_RS = result_line('Ridge Regression', 'RandomSearchCV', res_RS)
results = results.append(res_GS, ignore_index=True)
results = results.append(res_RS, ignore_index=True)

# %%
results
# Out:
#                  Model Search_strategy  train_neg_mean_absolute_error  \
# 0  Logistic Regression    GridSearchCV                      -14.29677
# 1  Logistic Regression  RandomSearchCV                      -14.28360
# 2     Ridge Regression    GridSearchCV                      -36.66271
# 3     Ridge Regression  RandomSearchCV                      -36.67376
#
#    train_neg_mean_squared_error  train_neg_median_absolute_error  \
# 0                    -958.82546                         -3.20000
# 1                    -999.73923                         -2.60000
# 2                  -3,248.74162                        -25.40493
# 3                  -3,246.06384                        -25.44607
#
#    test_neg_mean_absolute_error  test_neg_mean_squared_error  \
# 0                     -58.53833                -17,219.19547
# 1                     -61.64309                -17,748.60499
# 2                     -43.03567                 -6,302.03602
# 3                     -43.20924                 -6,341.13025
#
#    test_neg_median_absolute_error  fit_time  score_time
# 0                       -19.40000  87.50960     0.00280
# 1                       -20.80000  19.08596     0.00319
# 2                       -27.23790   0.14581     0.00299
# 3                       -27.13516   0.06782     0.00319

# %% [markdown]
# <h2 style="color:dark blue;"><i>Bayesian Regression</i></h2>

# %%
model3=linear_model.BayesianRidge()
model3.fit(X,y)
# Out:
# BayesianRidge(alpha_1=1e-06, alpha_2=1e-06, compute_score=False, copy_X=True,
#        fit_intercept=True, lambda_1=1e-06, lambda_2=1e-06, n_iter=300,
#        normalize=False, tol=0.001, verbose=False)

# %%
parameters = {
    'n_iter': [100, 300, 500],
    'alpha_1': [1e-10, 1e-5, 0.001, 1.0, 5.0, 8.0],
    'alpha_2': [1e-10, 1e-5, 0.001, 1.0, 5.0, 8.0],
    'lambda_1':[1e-10, 1e-5, 0.001, 1.0, 5.0, 8.0],
    'lambda_2':[1e-10, 1e-5, 0.001, 1.0, 5.0, 8.0]
} 
res_GS, res_RS = scores_report(model3, parameters=parameters)

res_GS = result_line('Bayesian Regression', 'GridSearchCV', res_GS)
res_RS = result_line('Bayesian Regression', 'RandomSearchCV', res_RS)
results = results.append(res_GS, ignore_index=True)
results = results.append(res_RS, ignore_index=True)

# %%
results
# Out:
#                  Model Search_strategy  train_neg_mean_absolute_error  \
# 0  Logistic Regression    GridSearchCV                      -14.29677
# 1  Logistic Regression  RandomSearchCV                      -14.28360
# 2     Ridge Regression    GridSearchCV                      -36.66271
# 3     Ridge Regression  RandomSearchCV                      -36.67376
# 4  Bayesian Regression    GridSearchCV                      -36.65246
# 5  Bayesian Regression  RandomSearchCV                      -36.65599
#
#    train_neg_mean_squared_error  train_neg_median_absolute_error  \
# 0                    -958.82546                         -3.20000
# 1                    -999.73923                         -2.60000
# 2                  -3,248.74162                        -25.40493
# 3                  -3,246.06384                        -25.44607
# 4                  -3,335.91773                        -25.85399
# 5                  -3,270.44452                        -25.39773
#
#    test_neg_mean_absolute_error  test_neg_mean_squared_error  \
# 0                     -58.53833                -17,219.19547
# 1                     -61.64309                -17,748.60499
# 2                     -43.03567                 -6,302.03602
# 3                     -43.20924                 -6,341.13025
# 4                     -42.10105                 -6,057.04935
# 5                     -42.01190                 -6,109.86332
#
#    test_neg_median_absolute_error  fit_time  score_time
# 0                       -19.40000  87.50960     0.00280
# 1                       -20.80000  19.08596     0.00319
# 2                       -27.23790   0.14581     0.00299
# 3                       -27.13516   0.06782     0.00319
# 4                       -27.34335  25.49982     0.00279
# 5                       -27.44240   0.07300     0.00279

# %% [markdown]
# <h2 style="color:dark orange;"><i>SGD Regressor</i></h2>

# %%
model4=linear_model.SGDRegressor(eta0=0.000001)
model4.fit(X,y)
# Out:
# SGDRegressor(alpha=0.0001, average=False, early_stopping=False, epsilon=0.1,
#        eta0=1e-06, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='invscaling', loss='squared_loss', max_iter=None,
#        n_iter=None, n_iter_no_change=5, penalty='l2', power_t=0.25,
#        random_state=None, shuffle=True, tol=None, validation_fraction=0.1,
#        verbose=0, warm_start=False)

# %%
parameters={
    'loss':['squared_loss', 'huber', 'squared_epsilon_insensitive'],
    'penalty':['l1', 'l2', 'elasticnet'],
    'alpha':[1e-8, 1e-3, 0.5, 3, 8],
    'max_iter':[200, 300, 800]
    
}
res_GS, res_RS = scores_report(model4, parameters=parameters)

res_GS = result_line('SGD Regressor', 'GridSearchCV', res_GS)
res_RS = result_line('SGD Regressor', 'RandomSearchCV', res_RS)
results = results.append(res_GS, ignore_index=True)
results = results.append(res_RS, ignore_index=True)

# %%
results
# Out:
#                  Model Search_strategy  train_neg_mean_absolute_error  \
# 0  Logistic Regression    GridSearchCV                      -14.29677
# 1  Logistic Regression  RandomSearchCV                      -14.28360
# 2     Ridge Regression    GridSearchCV                      -36.66271
# 3     Ridge Regression  RandomSearchCV                      -36.67376
# 4  Bayesian Regression    GridSearchCV                      -36.65246
# 5  Bayesian Regression  RandomSearchCV                      -36.65599
# 6        SGD Regressor    GridSearchCV                      -38.17227
# 7        SGD Regressor  RandomSearchCV                      -37.92370
#
#    train_neg_mean_squared_error  train_neg_median_absolute_error  \
# 0                    -958.82546                         -3.20000
# 1                    -999.73923                         -2.60000
# 2                  -3,248.74162                        -25.40493
# 3                  -3,246.06384                        -25.44607
# 4                  -3,335.91773                        -25.85399
# 5                  -3,270.44452                        -25.39773
# 6                  -7,561.83600                        -15.93617
# 7                  -7,287.67893                        -16.40216
#
#    test_neg_mean_absolute_error  test_neg_mean_squared_error  \
# 0                     -58.53833                -17,219.19547
# 1                     -61.64309                -17,748.60499
# 2                     -43.03567                 -6,302.03602
# 3                     -43.20924                 -6,341.13025
# 4                     -42.10105                 -6,057.04935
# 5                     -42.01190                 -6,109.86332
# 6                     -39.52775                 -7,870.96060
# 7                     -39.30310                 -7,735.41228
#
#    test_neg_median_absolute_error  fit_time  score_time
# 0                       -19.40000  87.50960     0.00280
# 1                       -20.80000  19.08596     0.00319
# 2                       -27.23790   0.14581     0.00299
# 3                       -27.13516   0.06782     0.00319
# 4                       -27.34335  25.49982     0.00279
# 5                       -27.44240   0.07300     0.00279
# 6                       -18.57828   5.94550     0.00319
# 7                       -18.45389   0.25771     0.00379

# %% [markdown]
# <h2 style="color:dark violet;"><i>Perceptron</i></h2>

# %%
model5=linear_model.Perceptron(tol=0.5)
model5.fit(X,y)
# Out:
# Perceptron(alpha=0.0001, class_weight=None, early_stopping=False, eta0=1.0,
#       fit_intercept=True, max_iter=None, n_iter=None, n_iter_no_change=5,
#       n_jobs=None, penalty=None, random_state=0, shuffle=True, tol=0.5,
#       validation_fraction=0.1, verbose=0, warm_start=False)

# %%
parameters= {
    'alpha':[1e-5, 1e-3, 0.5, 1, 8, 21],
    'max_iter': [200, 500, 800]
}
res_GS, res_RS = scores_report(model5, parameters=parameters)

res_GS = result_line('Perceptron', 'GridSearchCV', res_GS)
res_RS = result_line('Perceptron', 'RandomSearchCV', res_RS)
results = results.append(res_GS, ignore_index=True)
results = results.append(res_RS, ignore_index=True)

# %%
results
# Out:
#                  Model Search_strategy  train_neg_mean_absolute_error  \
# 0  Logistic Regression    GridSearchCV                      -14.29677
# 1  Logistic Regression  RandomSearchCV                      -14.28360
# 2     Ridge Regression    GridSearchCV                      -36.66271
# 3     Ridge Regression  RandomSearchCV                      -36.67376
# 4  Bayesian Regression    GridSearchCV                      -36.65246
# 5  Bayesian Regression  RandomSearchCV                      -36.65599
# 6        SGD Regressor    GridSearchCV                      -38.17227
# 7        SGD Regressor  RandomSearchCV                      -37.92370
# 8           Perceptron    GridSearchCV                     -125.96056
# 9           Perceptron  RandomSearchCV                     -125.96056
#
#    train_neg_mean_squared_error  train_neg_median_absolute_error  \
# 0                    -958.82546                         -3.20000
# 1                    -999.73923                         -2.60000
# 2                  -3,248.74162                        -25.40493
# 3                  -3,246.06384                        -25.44607
# 4                  -3,335.91773                        -25.85399
# 5                  -3,270.44452                        -25.39773
# 6                  -7,561.83600                        -15.93617
# 7                  -7,287.67893                        -16.40216
# 8                 -40,854.35105                        -92.80000
# 9                 -40,854.35105                        -92.80000
#
#    test_neg_mean_absolute_error  test_neg_mean_squared_error  \
# 0                     -58.53833                -17,219.19547
# 1                     -61.64309                -17,748.60499
# 2                     -43.03567                 -6,302.03602
# 3                     -43.20924                 -6,341.13025
# 4                     -42.10105                 -6,057.04935
# 5                     -42.01190                 -6,109.86332
# 6                     -39.52775                 -7,870.96060
# 7                     -39.30310                 -7,735.41228
# 8                    -123.92427                -41,200.61022
# 9                    -123.92427                -41,200.61022
#
#    test_neg_median_absolute_error  fit_time  score_time
# 0                       -19.40000  87.50960     0.00280
# 1                       -20.80000  19.08596     0.00319
# 2                       -27.23790   0.14581     0.00299
# 3                       -27.13516   0.06782     0.00319
# 4                       -27.34335  25.49982     0.00279
# 5                       -27.44240   0.07300     0.00279
# 6                       -18.57828   5.94550     0.00319
# 7                       -18.45389   0.25771     0.00379
# 8                       -95.00000   0.74521     0.00638
# 9                       -95.00000   0.41649     0.00419

# %%
results.iloc[:, 2:] = abs(results.iloc[:, 2:])
results
# Out:
#                  Model Search_strategy  train_neg_mean_absolute_error  \
# 0  Logistic Regression    GridSearchCV                       14.29677
# 1  Logistic Regression  RandomSearchCV                       14.28360
# 2     Ridge Regression    GridSearchCV                       36.66271
# 3     Ridge Regression  RandomSearchCV                       36.67376
# 4  Bayesian Regression    GridSearchCV                       36.65246
# 5  Bayesian Regression  RandomSearchCV                       36.65599
# 6        SGD Regressor    GridSearchCV                       38.17227
# 7        SGD Regressor  RandomSearchCV                       37.92370
# 8           Perceptron    GridSearchCV                      125.96056
# 9           Perceptron  RandomSearchCV                      125.96056
#
#    train_neg_mean_squared_error  train_neg_median_absolute_error  \
# 0                     958.82546                          3.20000
# 1                     999.73923                          2.60000
# 2                   3,248.74162                         25.40493
# 3                   3,246.06384                         25.44607
# 4                   3,335.91773                         25.85399
# 5                   3,270.44452                         25.39773
# 6                   7,561.83600                         15.93617
# 7                   7,287.67893                         16.40216
# 8                  40,854.35105                         92.80000
# 9                  40,854.35105                         92.80000
#
#    test_neg_mean_absolute_error  test_neg_mean_squared_error  \
# 0                      58.53833                 17,219.19547
# 1                      61.64309                 17,748.60499
# 2                      43.03567                  6,302.03602
# 3                      43.20924                  6,341.13025
# 4                      42.10105                  6,057.04935
# 5                      42.01190                  6,109.86332
# 6                      39.52775                  7,870.96060
# 7                      39.30310                  7,735.41228
# 8                     123.92427                 41,200.61022
# 9                     123.92427                 41,200.61022
#
#    test_neg_median_absolute_error  fit_time  score_time
# 0                        19.40000  87.50960     0.00280
# 1                        20.80000  19.08596     0.00319
# 2                        27.23790   0.14581     0.00299
# 3                        27.13516   0.06782     0.00319
# 4                        27.34335  25.49982     0.00279
# 5                        27.44240   0.07300     0.00279
# 6                        18.57828   5.94550     0.00319
# 7                        18.45389   0.25771     0.00379
# 8                        95.00000   0.74521     0.00638
# 9                        95.00000   0.41649     0.00419

# %%
def color(grid):
    return ['background-color: red' if value == grid.max() else ('background-color: green' if value == grid.min() else '') for value in grid]

# %%
results_highlighted= results.style.apply(color, subset=['train_neg_mean_absolute_error', 'train_neg_mean_squared_error', 'train_neg_median_absolute_error','test_neg_mean_absolute_error','test_neg_mean_squared_error','test_neg_median_absolute_error','fit_time','score_time'])

# %%
results_highlighted
# Out:
# <style  type="text/css" >
#     #T_4ce98726_7038_11e9_998d_54ab3ac1d674row0_col3 {
#             background-color:  green;
#         }    #T_4ce98726_7038_11e9_998d_54ab3ac1d674row0_col8 {
#             background-color:  red;
#         }    #T_4ce98726_7038_11e9_998d_54ab3ac1d674row1_col2 {
#             background-color:  green;
#         }    #T_4ce98726_7038_11e9_998d_54ab3ac1d674row1_col4 {
#             background-color:  green;
#         }    #T_4ce98726_7038_11e9_998d_54ab3ac1d674row3_col8 {
#             background-color:  green;
#         }    #T_4ce98726_7038_11e9_998d_54ab3ac1d674row4_col6 {
#             background-color:  green;
#         }    #T_4ce98726_7038_11e9_998d_54ab3ac1d674row4_col9 {
#             background-color:  green;
#         }    #T_4ce98726_7038_11e9_998d_54ab3ac1d674row7_col5 {
#             background-color:  green;
#         }    #T_4ce98726_7038_11e9_998d_54ab3ac1d674row7_col7 {
#             background-color:  green;
#         }    #T_4ce98726_7038_11e9_998d_54ab3ac1d674row8_col2 {
#             background-color:  red;
#         }    #T_4ce98726_7038_11e9_998d_54ab3ac1d674row8_col3 {
#             background-color:  red;
#         }    #T_4ce98726_7038_11e9_998d_54ab3ac1d674row8_col4 {
#             background-color:  red;
#         }    #T_4ce98726_7038_11e9_998d_54ab3ac1d674row8_col5 {
#             background-color:  red;
#         }    #T_4ce98726_7038_11e9_998d_54ab3ac1d674row8_col6 {
#             background-color:  red;
#         }    #T_4ce98726_7038_11e9_998d_54ab3ac1d674row8_col7 {
#             background-color:  red;
#         }    #T_4ce98726_7038_11e9_998d_54ab3ac1d674row8_col9 {
#             background-color:  red;
#         }    #T_4ce98726_7038_11e9_998d_54ab3ac1d674row9_col2 {
#             background-color:  red;
#         }    #T_4ce98726_7038_11e9_998d_54ab3ac1d674row9_col3 {
#             background-color:  red;
#         }    #T_4ce98726_7038_11e9_998d_54ab3ac1d674row9_col4 {
#             background-color:  red;
#         }    #T_4ce98726_7038_11e9_998d_54ab3ac1d674row9_col5 {
#             background-color:  red;
#         }    #T_4ce98726_7038_11e9_998d_54ab3ac1d674row9_col6 {
#             background-color:  red;
#         }    #T_4ce98726_7038_11e9_998d_54ab3ac1d674row9_col7 {
#             background-color:  red;
#         }</style>
# <table id="T_4ce98726_7038_11e9_998d_54ab3ac1d674" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Model</th>
#         <th class="col_heading level0 col1" >Search_strategy</th>
#         <th class="col_heading level0 col2" >train_neg_mean_absolute_error</th>
#         <th class="col_heading level0 col3" >train_neg_mean_squared_error</th>
#         <th class="col_heading level0 col4" >train_neg_median_absolute_error</th>
#         <th class="col_heading level0 col5" >test_neg_mean_absolute_error</th>
#         <th class="col_heading level0 col6" >test_neg_mean_squared_error</th>
#         <th class="col_heading level0 col7" >test_neg_median_absolute_error</th>
#         <th class="col_heading level0 col8" >fit_time</th>
#         <th class="col_heading level0 col9" >score_time</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_4ce98726_7038_11e9_998d_54ab3ac1d674level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_4ce98726_7038_11e9_998d_54ab3ac1d674row0_col0" class="data row0 col0" >Logistic Regression</td>
#         <td id="T_4ce98726_7038_11e9_998d_54ab3ac1d674row0_col1" class="data row0 col1" >GridSearchCV</td>
#         <td id="T_4ce98726_7038_11e9_998d_54ab3ac1d674row0_col2" class="data row0 col2" >14.2968</td>
#         <td id="T_4ce98726_7038_11e9_998d_54ab3ac1d674row0_col3" class="data row0 col3" >958.825</td>
#         <td id="T_4ce98726_7038_11e9_998d_54ab3ac1d674row0_col4" class="data row0 col4" >3.2</td>
#         <td id="T_4ce98726_7038_11e9_998d_54ab3ac1d674row0_col5" class="data row0 col5" >58.5383</td>
#         <td id="T_4ce98726_7038_11e9_998d_54ab3ac1d674row0_col6" class="data row0 col6" >17219.2</td>
#         <td id="T_4ce98726_7038_11e9_998d_54ab3ac1d674row0_col7" class="data row0 col7" >19.4</td>
#         <td id="T_4ce98726_7038_11e9_998d_54ab3ac1d674row0_col8" class="data row0 col8" >87.5096</td>
#         <td id="T_4ce98726_7038_11e9_998d_54ab3ac1d674row0_col9" class="data row0 col9" >0.00279512</td>
#     </tr>    <tr>
#         <th id="T_4ce98726_7038_11e9_998d_54ab3ac1d674level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_4ce98726_7038_11e9_998d_54ab3ac1d674row1_col0" class="data row1 col0" >Logistic Regression</td>
#         <td id="T_4ce98726_7038_11e9_998d_54ab3ac1d674row1_col1" class="data row1 col1" >RandomSearchCV</td>
#         <td id="T_4ce98726_7038_11e9_998d_54ab3ac1d674row1_col2" class="data row1 col2" >14.2836</td>
#         <td id="T_4ce98726_7038_11e9_998d_54ab3ac1d674row1_col3" class="data row1 col3" >999.739</td>
#         <td id="T_4ce98726_7038_11e9_998d_54ab3ac1d674row1_col4" class="data row1 col4" >2.6</td>
#         <td id="T_4ce98726_7038_11e9_998d_54ab3ac1d674row1_col5" class="data row1 col5" >61.6431</td>
#         <td id="T_4ce98726_7038_11e9_998d_54ab3ac1d674row1_col6" class="data row1 col6" >17748.6</td>
#         <td id="T_4ce98726_7038_11e9_998d_54ab3ac1d674row1_col7" class="data row1 col7" >20.8</td>
#         <td id="T_4ce98726_7038_11e9_998d_54ab3ac1d674row1_col8" class="data row1 col8" >19.086</td>
#         <td id="T_4ce98726_7038_11e9_998d_54ab3ac1d674row1_col9" class="data row1 col9" >0.003192</td>
#     </tr>    <tr>
#         <th id="T_4ce98726_7038_11e9_998d_54ab3ac1d674level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_4ce98726_7038_11e9_998d_54ab3ac1d674row2_col0" class="data row2 col0" >Ridge Regression</td>
#         <td id="T_4ce98726_7038_11e9_998d_54ab3ac1d674row2_col1" class="data row2 col1" >GridSearchCV</td>
#         <td id="T_4ce98726_7038_11e9_998d_54ab3ac1d674row2_col2" class="data row2 col2" >36.6627</td>
#         <td id="T_4ce98726_7038_11e9_998d_54ab3ac1d674row2_col3" class="data row2 col3" >3248.74</td>
#         <td id="T_4ce98726_7038_11e9_998d_54ab3ac1d674row2_col4" class="data row2 col4" >25.4049</td>
#         <td id="T_4ce98726_7038_11e9_998d_54ab3ac1d674row2_col5" class="data row2 col5" >43.0357</td>
#         <td id="T_4ce98726_7038_11e9_998d_54ab3ac1d674row2_col6" class="data row2 col6" >6302.04</td>
#         <td id="T_4ce98726_7038_11e9_998d_54ab3ac1d674row2_col7" class="data row2 col7" >27.2379</td>
#         <td id="T_4ce98726_7038_11e9_998d_54ab3ac1d674row2_col8" class="data row2 col8" >0.14581</td>
#         <td id="T_4ce98726_7038_11e9_998d_54ab3ac1d674row2_col9" class="data row2 col9" >0.00299177</td>
#     </tr>    <tr>
#         <th id="T_4ce98726_7038_11e9_998d_54ab3ac1d674level0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_4ce98726_7038_11e9_998d_54ab3ac1d674row3_col0" class="data row3 col0" >Ridge Regression</td>
#         <td id="T_4ce98726_7038_11e9_998d_54ab3ac1d674row3_col1" class="data row3 col1" >RandomSearchCV</td>
#         <td id="T_4ce98726_7038_11e9_998d_54ab3ac1d674row3_col2" class="data row3 col2" >36.6738</td>
#         <td id="T_4ce98726_7038_11e9_998d_54ab3ac1d674row3_col3" class="data row3 col3" >3246.06</td>
#         <td id="T_4ce98726_7038_11e9_998d_54ab3ac1d674row3_col4" class="data row3 col4" >25.4461</td>
#         <td id="T_4ce98726_7038_11e9_998d_54ab3ac1d674row3_col5" class="data row3 col5" >43.2092</td>
#         <td id="T_4ce98726_7038_11e9_998d_54ab3ac1d674row3_col6" class="data row3 col6" >6341.13</td>
#         <td id="T_4ce98726_7038_11e9_998d_54ab3ac1d674row3_col7" class="data row3 col7" >27.1352</td>
#         <td id="T_4ce98726_7038_11e9_998d_54ab3ac1d674row3_col8" class="data row3 col8" >0.0678193</td>
#         <td id="T_4ce98726_7038_11e9_998d_54ab3ac1d674row3_col9" class="data row3 col9" >0.00319085</td>
#     </tr>    <tr>
#         <th id="T_4ce98726_7038_11e9_998d_54ab3ac1d674level0_row4" class="row_heading level0 row4" >4</th>
#         <td id="T_4ce98726_7038_11e9_998d_54ab3ac1d674row4_col0" clas
