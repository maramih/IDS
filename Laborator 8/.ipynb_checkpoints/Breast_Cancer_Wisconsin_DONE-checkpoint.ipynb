# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_validate

# %%
# %%HTML
# <style type="text/css">
# table.dataframe td, table.dataframe th {
#     border: 1px  black solid !important;
#   color: black !important;
# }
# </style>
# Out:
# <style type="text/css">
# table.dataframe td, table.dataframe th {
#     border: 1px  black solid !important;
#   color: black !important;
# }
# </style>

# %%
def error_report(model, parameters):
    model_GS = GridSearchCV(model, param_grid=parameters, cv = 3, iid = False, return_train_score=True, n_jobs=-1)
    model_RS = RandomizedSearchCV(estimator = model, param_distributions = parameters, cv=3, n_iter=4, iid=False, n_jobs=-1)
    scores_GS = cross_validate(model_GS, x_set, y_set, return_train_score=True, scoring=('neg_mean_absolute_error', 'neg_mean_squared_error', 'neg_median_absolute_error'),cv=5)
    scores_RS = cross_validate(model_RS, x_set, y_set, return_train_score=True, scoring=('neg_mean_absolute_error', 'neg_mean_squared_error', 'neg_median_absolute_error'),cv=5)
    return scores_GS, scores_RS

# %%
def make_line(model:str, search_strategy:str, results):
    for key, value in results.items():
        results[key] = results[key].mean()
    results['Model'] = model
    results['Search_strategy'] = search_strategy
    return results

# %%
namesDict = ["ID", "Clump Thickness", "Uniformity of Cell Size", "Uniformity of Cell Shape", "Marginal Adhesion",
             "Single Epithelial Cell Size", "Bare Nuclei", "Bland Chromatin", "Normal Nucleoli", "Mitoses", "Class"]
data_set = pd.read_csv('breast-cancer-wisconsin.data', names = namesDict)
data_set = data_set.iloc[:, 1:]
data_set = data_set[data_set["Bare Nuclei"] != '?']
data_set['Bare Nuclei'] = data_set['Bare Nuclei'].astype(int)

# %%
x_set = data_set.iloc[:, :9]
y_set = data_set.iloc[:, 9]
y_set = np.ravel(y_set)

# %%
results = pd.DataFrame(columns = ['Model','Search_strategy','train_neg_mean_absolute_error',
                                  'train_neg_mean_squared_error',
                                  'train_neg_median_absolute_error', 'test_neg_mean_absolute_error',
                                  'test_neg_mean_squared_error',
                                  'test_neg_median_absolute_error', 'fit_time', 'score_time'])

# %%
from sklearn import linear_model

# %% [markdown]
# ## Ridge Regression

# %%
parameters = {'alpha':[0.1, 0.5, 1, 2, 3, 5, 8, 13, 1000, 5000]
             }

res_GS, res_RS = error_report(linear_model.Ridge(), parameters=parameters)

res_GS = make_line('Ridge Regression', 'GridSearchCV', res_GS)
res_RS = make_line('Ridge Regression', 'RandomSearchCV', res_RS)
results = results.append(res_GS, ignore_index=True)
results = results.append(res_RS, ignore_index=True)

# %% [markdown]
# ## Bayesian Regression

# %%
parameters = {
    'n_iter': [100, 300, 500],
    'alpha_1': [1e-10, 1e-5, 0.001, 1.0, 5.0, 8.0],
    'alpha_2': [1e-10, 1e-5, 0.001, 1.0, 5.0, 8.0],
    'lambda_1':[1e-10, 1e-5, 0.001, 1.0, 5.0, 8.0],
    'lambda_2':[1e-10, 1e-5, 0.001, 1.0, 5.0, 8.0]
} 
res_GS, res_RS = error_report(linear_model.BayesianRidge(), parameters=parameters)

res_GS = make_line('Bayesian Regression', 'GridSearchCV', res_GS)
res_RS = make_line('Bayesian Regression', 'RandomSearchCV', res_RS)
results = results.append(res_GS, ignore_index=True)
results = results.append(res_RS, ignore_index=True)

# %% [markdown]
# ## Logistic Regression

# %%
parameters={
    'solver': ['lbfgs'],
    'C':[0.1, 1.0, 2, 5, 13, 21],
    'max_iter':[100, 300, 500]
}
res_GS, res_RS = error_report(linear_model.LogisticRegression(), parameters=parameters)

res_GS = make_line('Logistic Regression', 'GridSearchCV', res_GS)
res_RS = make_line('Logistic Regression', 'RandomSearchCV', res_RS)
results = results.append(res_GS, ignore_index=True)
results = results.append(res_RS, ignore_index=True)

# %% [markdown]
# ## Perceptron

# %%
parameters= {
    'alpha':[1e-5, 1e-3, 0.5, 1, 8, 21],
    'max_iter': [200, 500, 1000]
}
res_GS, res_RS = error_report(linear_model.Perceptron(tol=0.21), parameters=parameters)

res_GS = make_line('Perceptron', 'GridSearchCV', res_GS)
res_RS = make_line('Perceptron', 'RandomSearchCV', res_RS)
results = results.append(res_GS, ignore_index=True)
results = results.append(res_RS, ignore_index=True)

# %% [markdown]
# ## SGDRegressor

# %%
parameters={
    'loss':['squared_loss', 'huber', 'squared_epsilon_insensitive'],
    'penalty':['l1', 'l2', 'elasticnet'],
    'alpha':[1e-8, 1e-3, 0.5, 3, 8],
    'max_iter':[200, 300, 800]
    
}
res_GS, res_RS = error_report(linear_model.SGDRegressor(tol=1e-3), parameters=parameters)
res_GS = make_line('SGD Regressor', 'GridSearchCV', res_GS)
res_RS = make_line('SGD Regressor', 'RandomSearchCV', res_RS)
results = results.append(res_GS, ignore_index=True)
results = results.append(res_RS, ignore_index=True)

# %%
results.head(10)
# Out:
#                  Model Search_strategy  train_neg_mean_absolute_error  \
# 0     Ridge Regression    GridSearchCV                      -0.246551
# 1     Ridge Regression  RandomSearchCV                      -0.245547
# 2  Bayesian Regression    GridSearchCV                      -0.244429
# 3  Bayesian Regression  RandomSearchCV                      -0.244281
# 4  Logistic Regression    GridSearchCV                      -0.056357
# 5  Logistic Regression  RandomSearchCV                      -0.056357
# 6           Perceptron    GridSearchCV                      -0.214919
# 7           Perceptron  RandomSearchCV                      -0.214919
# 8        SGD Regressor    GridSearchCV                      -0.260820
# 9        SGD Regressor  RandomSearchCV                      -0.290716
#
#    train_neg_mean_squared_error  train_neg_median_absolute_error  \
# 0                     -0.142371                        -0.144900
# 1                     -0.141438                        -0.141478
# 2                     -0.140670                        -0.141635
# 3                     -0.140504                        -0.142905
# 4                     -0.112714                         0.000000
# 5                     -0.112714                         0.000000
# 6                     -0.429839                         0.000000
# 7                     -0.429839                         0.000000
# 8                     -0.160984                        -0.143188
# 9                     -0.171694                        -0.201580
#
#    test_neg_mean_absolute_error  test_neg_mean_squared_error  \
# 0                     -0.264596                    -0.160251
# 1                     -0.265214                    -0.161179
# 2                     -0.265565                    -0.160477
# 3                     -0.266988                    -0.161768
# 4                     -0.070116                    -0.140232
# 5                     -0.064277                    -0.128554
# 6                     -0.217918                    -0.435837
# 7                     -0.217918                    -0.435837
# 8                     -0.281495                    -0.179569
# 9                     -0.314938                    -0.200308
#
#    test_neg_median_absolute_error   fit_time  score_time
# 0                       -0.166859   9.842327    0.000000
# 1                       -0.164832   0.065603    0.003125
# 2                       -0.160422  35.313071    0.006114
# 3                       -0.162295   0.081397    0.000798
# 4                        0.000000   0.516120    0.008495
# 5                        0.000000   0.118692    0.003125
# 6                        0.000000   0.271258    0.002593
# 7                        0.000000   0.072604    0.003990
# 8                       -0.171607   1.367118    0.000798
# 9                       -0.216301   0.081230    0.000000

# %%
pd.options.display.float_format = '{5:.5f}'.format

# %%
results.iloc[:, 2:] = abs(results.iloc[:, 2:])

# %%
def myhighlight(x):
    return ['background-color: red' if v == x.max() else ('background-color: green' if v == x.min() else '') for v in x]

# %%
final_results = results.style.apply(myhighlight, subset=['train_neg_mean_absolute_error', 'train_neg_mean_squared_error', 'train_neg_median_absolute_error','test_neg_mean_absolute_error','test_neg_mean_squared_error','test_neg_median_absolute_error','fit_time','score_time'])

# %%
final_results
# Out:
# <style  type="text/css" >
#     #T_1481b56e_6cbf_11e9_85d0_9c305b625908row0_col9 {
#             background-color:  green;
#         }    #T_1481b56e_6cbf_11e9_85d0_9c305b625908row1_col8 {
#             background-color:  green;
#         }    #T_1481b56e_6cbf_11e9_85d0_9c305b625908row2_col8 {
#             background-color:  red;
#         }    #T_1481b56e_6cbf_11e9_85d0_9c305b625908row4_col2 {
#             background-color:  green;
#         }    #T_1481b56e_6cbf_11e9_85d0_9c305b625908row4_col3 {
#             background-color:  green;
#         }    #T_1481b56e_6cbf_11e9_85d0_9c305b625908row4_col4 {
#             background-color:  green;
#         }    #T_1481b56e_6cbf_11e9_85d0_9c305b625908row4_col7 {
#             background-color:  green;
#         }    #T_1481b56e_6cbf_11e9_85d0_9c305b625908row4_col9 {
#             background-color:  red;
#         }    #T_1481b56e_6cbf_11e9_85d0_9c305b625908row5_col2 {
#             background-color:  green;
#         }    #T_1481b56e_6cbf_11e9_85d0_9c305b625908row5_col3 {
#             background-color:  green;
#         }    #T_1481b56e_6cbf_11e9_85d0_9c305b625908row5_col4 {
#             background-color:  green;
#         }    #T_1481b56e_6cbf_11e9_85d0_9c305b625908row5_col5 {
#             background-color:  green;
#         }    #T_1481b56e_6cbf_11e9_85d0_9c305b625908row5_col6 {
#             background-color:  green;
#         }    #T_1481b56e_6cbf_11e9_85d0_9c305b625908row5_col7 {
#             background-color:  green;
#         }    #T_1481b56e_6cbf_11e9_85d0_9c305b625908row6_col3 {
#             background-color:  red;
#         }    #T_1481b56e_6cbf_11e9_85d0_9c305b625908row6_col4 {
#             background-color:  green;
#         }    #T_1481b56e_6cbf_11e9_85d0_9c305b625908row6_col6 {
#             background-color:  red;
#         }    #T_1481b56e_6cbf_11e9_85d0_9c305b625908row6_col7 {
#             background-color:  green;
#         }    #T_1481b56e_6cbf_11e9_85d0_9c305b625908row7_col3 {
#             background-color:  red;
#         }    #T_1481b56e_6cbf_11e9_85d0_9c305b625908row7_col4 {
#             background-color:  green;
#         }    #T_1481b56e_6cbf_11e9_85d0_9c305b625908row7_col6 {
#             background-color:  red;
#         }    #T_1481b56e_6cbf_11e9_85d0_9c305b625908row7_col7 {
#             background-color:  green;
#         }    #T_1481b56e_6cbf_11e9_85d0_9c305b625908row9_col2 {
#             background-color:  red;
#         }    #T_1481b56e_6cbf_11e9_85d0_9c305b625908row9_col4 {
#             background-color:  red;
#         }    #T_1481b56e_6cbf_11e9_85d0_9c305b625908row9_col5 {
#             background-color:  red;
#         }    #T_1481b56e_6cbf_11e9_85d0_9c305b625908row9_col7 {
#             background-color:  red;
#         }    #T_1481b56e_6cbf_11e9_85d0_9c305b625908row9_col9 {
#             background-color:  green;
#         }</style><table id="T_1481b56e_6cbf_11e9_85d0_9c305b625908" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Search_strategy</th>        <th class="col_heading level0 col2" >train_neg_mean_absolute_error</th>        <th class="col_heading level0 col3" >train_neg_mean_squared_error</th>        <th class="col_heading level0 col4" >train_neg_median_absolute_error</th>        <th class="col_heading level0 col5" >test_neg_mean_absolute_error</th>        <th class="col_heading level0 col6" >test_neg_mean_squared_error</th>        <th class="col_heading level0 col7" >test_neg_median_absolute_error</th>        <th class="col_heading level0 col8" >fit_time</th>        <th class="col_heading level0 col9" >score_time</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1481b56e_6cbf_11e9_85d0_9c305b625908level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_1481b56e_6cbf_11e9_85d0_9c305b625908row0_col0" class="data row0 col0" >Ridge Regression</td>
#                         <td id="T_1481b56e_6cbf_11e9_85d0_9c305b625908row0_col1" class="data row0 col1" >GridSearchCV</td>
#                         <td id="T_1481b56e_6cbf_11e9_85d0_9c305b625908row0_col2" class="data row0 col2" >0.246551</td>
#                         <td id="T_1481b56e_6cbf_11e9_85d0_9c305b625908row0_col3" class="data row0 col3" >0.142371</td>
#                         <td id="T_1481b56e_6cbf_11e9_85d0_9c305b625908row0_col4" class="data row0 col4" >0.1449</td>
#                         <td id="T_1481b56e_6cbf_11e9_85d0_9c305b625908row0_col5" class="data row0 col5" >0.264596</td>
#                         <td id="T_1481b56e_6cbf_11e9_85d0_9c305b625908row0_col6" class="data row0 col6" >0.160251</td>
#                         <td id="T_1481b56e_6cbf_11e9_85d0_9c305b625908row0_col7" class="data row0 col7" >0.166859</td>
#                         <td id="T_1481b56e_6cbf_11e9_85d0_9c305b625908row0_col8" class="data row0 col8" >9.84233</td>
#                         <td id="T_1481b56e_6cbf_11e9_85d0_9c305b625908row0_col9" class="data row0 col9" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_1481b56e_6cbf_11e9_85d0_9c305b625908level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_1481b56e_6cbf_11e9_85d0_9c305b625908row1_col0" class="data row1 col0" >Ridge Regression</td>
#                         <td id="T_1481b56e_6cbf_11e9_85d0_9c305b625908row1_col1" class="data row1 col1" >RandomSearchCV</td>
#                         <td id="T_1481b56e_6cbf_11e9_85d0_9c305b625908row1_col2" class="data row1 col2" >0.245547</td>
#                         <td id="T_1481b56e_6cbf_11e9_85d0_9c305b625908row1_col3" class="data row1 col3" >0.141438</td>
#                         <td id="T_1481b56e_6cbf_11e9_85d0_9c305b625908row1_col4" class="data row1 col4" >0.141478</td>
#                         <td id="T_1481b56e_6cbf_11e9_85d0_9c305b625908row1_col5" class="data row1 col5" >0.265214</td>
#                         <td id="T_1481b56e_6cbf_11e9_85d0_9c305b625908row1_col6" class="data row1 col6" >0.161179</td>
#                         <td id="T_1481b56e_6cbf_11e9_85d0_9c305b625908row1_col7" class="data row1 col7" >0.164832</td>
#                         <td id="T_1481b56e_6cbf_11e9_85d0_9c305b625908row1_col8" class="data row1 col8" >0.065603</td>
#                         <td id="T_1481b56e_6cbf_11e9_85d0_9c305b625908row1_col9" class="data row1 col9" >0.00312452</td>
#             </tr>
#             <tr>
#                         <th id="T_1481b56e_6cbf_11e9_85d0_9c305b625908level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_1481b56e_6cbf_11e9_85d0_9c305b625908row2_col0" class="data row2 col0" >Bayesian Regression</td>
#                         <td id="T_1481b56e_6cbf_11e9_85d0_9c305b625908row2_col1" class="data row2 col1" >GridSearchCV</td>
#                         <td id="T_1481b56e_6cbf_11e9_85d0_9c305b625908row2_col2" class="data row2 col2" >0.244429</td>
#                         <td id="T_1481b56e_6cbf_11e9_85d0_9c305b625908row2_col3" class="data row2 col3" >0.14067</td>
#                         <td id="T_1481b56e_6cbf_11e9_85d0_9c305b625908row2_col4" class="data row2 col4" >0.141635</td>
#                         <td id="T_1481b56e_6cbf_11e9_85d0_9c305b625908row2_col5" class="data row2 col5" >0.265565</td>
#                         <td id="T_1481b56e_6cbf_11e9_85d0_9c305b625908row2_col6" class="data row2 col6" >0.160477</td>
#                         <td id="T_1481b56e_6cbf_11e9_85d0_9c305b625908row2_col7" class="data row2 col7" >0.160422</td>
#                         <td id="T_1481b56e_6cbf_11e9_85d0_9c305b625908row2_col8" class="data row2 col8" >35.3131</td>
#                         <td id="T_1481b56e_6cbf_11e9_85d0_9c305b625908row2_col9" class="data row2 col9" >0.00611401</td>
#             </tr>
#             <tr>
#                         <th id="T_1481b56e_6cbf_11e9_85d0_9c305b625908level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_1481b56e_6cbf_11e9_85d0_9c305b625908row3_col0" class="data row3 col0" >Bayesian Regression</td>
#                         <td id="T_1481b
